# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data structure: [restaurant_id, 2021, 2022, 2023, 2024]

sales_data = np.array([
    [1, 150000, 180000, 220000, 250000],  # Paradise Biryani
    [2, 120000, 140000, 160000, 190000],  # Beijing Bites
    [3, 200000, 230000, 260000, 300000],  # Pizza Hub
    [4, 180000, 210000, 240000, 270000],  # Burger Point
    [5, 160000, 185000, 205000, 230000]   # Chai Point
])
print("===== swiggy =======")
print("\nsale data shape",sales_data.shape)
print("\nfor first three rows: ", sales_data[1:4])
# Out:
# ===== swiggy =======
#
# sale data shape (5, 5)
#
# for first three rows:  [[     2 120000 140000 160000 190000]
#  [     3 200000 230000 260000 300000]
#  [     4 180000 210000 240000 270000]]

# %%
#total sale per year
print(np.sum(sales_data,axis=0))
yearly_total = np.sum(sales_data[:, 2:],axis=0)
print(yearly_total)
print(np.sum(yearly_total))


#min sales analysis

min_sales = np.min(sales_data[:, 1:], axis=1)
print(min_sales)

#max sales per year
max_sales = np.max(sales_data[:, 1:], axis=0)
print(max_sales)

# average per rest
avg_sales = np.mean(sales_data[:, 1:], axis=1)
print(avg_sales)

#cumsum
cumsum = np.cumsum(sales_data[:, 1:], axis=1)
print(cumsum)
# Out:
# [     15  810000  945000 1085000 1240000]
# [ 945000 1085000 1240000]
# 3270000
# [150000 120000 200000 180000 160000]
# [200000 230000 260000 300000]
# [200000. 152500. 247500. 225000. 195000.]
# [[150000 330000 550000 800000]
#  [120000 260000 420000 610000]
#  [200000 430000 690000 990000]
#  [180000 390000 630000 900000]
#  [160000 345000 550000 780000]]

# %%
plt.Figure(figsize=(10 ,6))
plt.plot(np.mean(cumsum , axis=0))
plt.title("avearge sales per year")
plt.xlabel("year")
plt.ylabel("sales")
plt.grid(True)
plt.show()

# %%
vector1 = np.array([1, 2, 3, 4, 5])
vector2 = np.array([6, 7, 8, 9, 10])
print("\nadding the vectors: ",vector1 + vector2)

print("\n multiplication vector ",vector1 * vector2)

print("\ndot product the vectors: ",np.dot(vector1 , vector2))
# Out:
# adding the vectors:  [ 7  9 11 13 15]
#
#  multiplication vector  [ 6 14 24 36 50]
#
# dot product the vectors:  130
